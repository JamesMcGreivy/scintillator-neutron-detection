# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
plt.style.use('seaborn')

# %%
# Parameters to Read
particle = "neutron"
energy = "0.1"
unit = "MeV"

try:
    os.mkdir("Edep/"+particle+energy+unit)
except:
    pass
# Reads in raw data from
data = pd.read_csv("../EJ309-build/data/" + particle + "_" + energy + "_" + unit + ".csv")
print(data[0:10])
data = np.array(data)
# Data organized as:
# particleID / parentID / pType/ eDep (eV) / materialName / currKE (eV)
# Out:
#    trackID  parentID    pType      eDep(eV) materialName    currKE(eV)
# 0   100000         0  neutron  0.000000e+00        ej309  2.546274e+06
# 1   100000         0  neutron  0.000000e+00        ej309  2.546274e+06
# 2   100001    100000   proton  2.194142e+06        ej309  1.661673e+06
# 3   100001    100000   proton  1.439664e+06        ej309  2.220087e+05
# 4   100001    100000   proton  2.080146e+05        ej309  1.399410e+04
# 5   100001    100000   proton  5.698065e+03        ej309  8.296035e+03
# 6   100001    100000   proton  8.296035e+03        ej309  0.000000e+00
# 7    99999         0  neutron  0.000000e+00        ej309  6.400000e+06
# 8    99998         0  neutron  0.000000e+00        ej309  6.400000e+06
# 9    99997         0  neutron  0.000000e+00        ej309  6.400000e+06

# %%
ptcls = {}
for x in data:
    ptcls[x[2]] = 0
print(ptcls.keys())
# Out:
# dict_keys(['neutron', 'proton', 'C12', 'gamma', 'e-', 'Be9', 'alpha', 'C13', 'deuteron', 'e+', 'Be10', 'anti_nu_e', 'B10', 'N13', 'nu_e'])

# %%
# Creates a "particle tree" which is a dictionary containing
# { event0 : {ptcls} , event1 : {ptcls} , ... }
# "ptcls" contains:
# { ptclID : { "allEvents" : [] , "children" : {ptcls} } }
# where "allEvents" is every event performed by the particle with ID == ptclID
# and "children" recursively stores "ptcls" structures for each child

IDtoRow = {}
for row in data:
    ptclID = row[0]
    IDtoRow[ptclID] = row

ptclTree = {}

for row in data:

    # Stack of parents
    IDStack = []
    ID = row[0]
    while ID > 0:
        IDStack.append(ID)
        if ID not in IDtoRow:
            IDStack.append(-1)
            break
        ID = IDtoRow[ID][1]

    currTree = ptclTree

    ID = 0
    while True:
        ID = IDStack.pop()
        if ID not in currTree:
            currTree[ID] = {"allEvents" : [] , "children" : {} , "totalEDep" : -1}

        if len(IDStack) == 0:
            currTree = currTree[ID]
            break

        currTree = currTree[ID]["children"]

    currTree["allEvents"].append(row)
    
ignored = ptclTree.pop(-1, 0)

# %%
# Takes in a "ptcl" and a material name, and finds the total energy deposited 
# by this particle, and all of its children, into that material

def netEDep(ptclInTree, materialName):
    eDep = 0
    for event in ptclInTree["allEvents"]:
        if event[4] in materialName:
            eDep += event[3]
    for child in ptclInTree["children"].values():
        eDep += netEDep(child, materialName)
    ptclInTree["totalEDep"] = eDep
    return eDep

# %%
def hasNoChildrenOfType(ptclInTree, ptclType):
    hasChild = True
    
    if ptclInTree["allEvents"][0][2] in ptclType:
        return False
    
    for child in ptclInTree["children"].values():
        hasChild = hasChild and hasNoChildrenOfType(child, ptclType)
    
    return hasChild

# %%
IDtoEdep = {}

for ptclID in ptclTree:
    eDep = netEDep(ptclTree[ptclID], "ej309")
    if eDep > 0.0:
        IDtoEdep[ptclID] = eDep

# %%
Edepo = np.array(list(IDtoEdep.values()))

# %%
plt.hist(Edepo / 1000.0, bins = 1000, range = (0, float(energy) * 1000.0))
plt.xlabel("energy deposited (keV)")
plt.ylabel("counts")
plt.title("Energy Deposit PDF of " 
         + energy + " " + unit + " " + particle + " Source"  
         + " \n Excluding any Neutrons which Interact w/ Carbon Ions")

plt.savefig("Edep/"+particle+energy+unit+"/Edep.eps")

# %%
plt.hist(Edepo / 1000.0, bins = 200)
plt.xlabel("energy deposited (keV)")
plt.ylabel("counts")
plt.title("Energy Deposit PDF of " 
              + energy + " " + unit + " " + particle 
              + " Source \n (numEvents = " + str(len(Edepo)) + ")")
plt.yscale("log")
plt.savefig("Edep/"+particle+energy+unit+"/Edep_FULLRANGE.eps")

# %%
import matplotlib
# x axis num of scatters, y axis eDep

IDtoNumScatters = {}
for ptclID in ptclTree:
    IDtoNumScatters[ptclID] = len(ptclTree[ptclID]["children"])

x = []
y = []

event = 0
for ID in IDtoEdep:
    x.append(IDtoNumScatters[ID])
    y.append(IDtoEdep[ID] / 1000.0)

# %%
plt.hist2d(x, y, bins = (15, 50), range = ( (0, 15) , (0, float(energy) * 1000.0) ), cmap=plt.cm.jet)
plt.xlabel("Num Scatters")
plt.ylabel("Edep (keV)")
plt.title("Number of Particles for a given Edep and Number of Scatters \n "
          + energy + " " + unit + " " + particle + " Source")
cbar = plt.colorbar()
cbar.set_label("counts")
plt.savefig("Edep/"+particle+energy+unit+"/scatters.eps")

# %%
OneSIDtoEdep = {}

for ptclID in ptclTree:
    if IDtoNumScatters[ptclID] == 1 and hasNoChildrenOfType(ptclTree[ptclID], "e- gamma C12 C13"):
        eDep = netEDep(ptclTree[ptclID], "ej309")
        if eDep > 0.0:
            OneSIDtoEdep[ptclID] = eDep

plt.hist(np.array(list(OneSIDtoEdep.values())) / 1000.0, bins=100)
plt.xlabel("energy deposited (keV)")
plt.ylabel("counts")
plt.title("Energy Deposit PDF of " 
         + energy + " " + unit + " " + particle + " Source"  
         + " \n Excluding any Neutrons which Interact w/ Carbon Ions"
         + " \n and which Interact with Multiple Protons")
plt.savefig("Edep/"+particle+energy+unit+"/Edep_ONESCATTER.eps")

# %%
OneSIDtoEdep
# Out:
# {99988: 149222.31199400002,
#  99976: 183537.289399,
#  99969: 245161.169319,
#  99968: 352062.78375999996,
#  99967: 162254.919903,
#  99966: 67509.26792299999,
#  99929: 250342.805692,
#  99927: 136484.798756,
#  99925: 172020.54174000002,
#  99921: 387871.580387,
#  99910: 95887.132701,
#  99909: 300402.884064,
#  99906: 342239.76429099997,
#  99884: 50072.550581,
#  99869: 114341.43319,
#  99855: 318958.365756,
#  99848: 140887.49933800002,
#  99845: 283766.444044,
#  99842: 38248.28886,
#  99837: 43777.158741,
#  99835: 349554.84743699996,
#  99828: 13910.647406999999,
#  99827: 76025.701231,
#  99809: 317196.849194,
#  99772: 365019.508407,
#  99770: 396585.96843400004,
#  99768: 317004.536482,
#  99752: 273714.201704,
#  99749: 28002.045965,
#  92703: 320743.44401599996,
#  92698: 31099.723382,
#  92696: 224142.586798,
#  92682: 96149.44434700001,
#  92679: 332262.946734,
#  92671: 181160.50790700002,
#  92666: 351541.691481,
#  92665: 27497.451096999997,
#  92650: 102098.02716,
#  92644: 116253.643029,
#  92632: 205374.200127,
#  92629: 203417.01907700003,
#  92615: 331744.66016200004,
#  92606: 14938.815342999998,
#  92604: 110937.231222,
#  92602: 259271.38613199999,
#  92589: 232031.664627,
#  92582: 6318.473897,
#  92566: 34019.671212,
#  92554: 54079.95404099999,
#  92550: 161383.14158199998,
#  92548: 125762.83476799999,
#  92530: 9551.344176999999,
#  92519: 209931.956417,
#  92518: 66703.18285800001,
#  92506: 114013.14243200001,
#  92500: 267177.751887,
#  92464: 56582.536261,
#  92460: 154186.882231,
#  92459: 146505.80044500003,
#  92456: 362670.862797,
#  92444: 191758.935376,
#  92436: 7725.967279,
#  92435: 85281.34548300001,
#  92431: 173694.825074,
#  92429: 321309.495711,
#  92421: 367273.879029,
#  92399: 22507.562862,
#  92396: 309562.14560499997,
#  92395: 307626.91334,
#  92393: 296834.785789,
#  92382: 278061.177135,
#  92378: 329162.249388,
#  92370: 50731.262508,
#  92353: 98322.63197999999,
#  92346: 202807.725913,
#  92342: 327961.080536,
#  92340: 84555.017247,
#  92338: 339714.413533,
#  92337: 64445.13599699999,
#  92335: 271695.667382,
#  92333: 202050.07962700003,
#  92328: 86392.050586,
#  92314: 200147.41269800003,
#  92306: 324753.83317399997,
#  92297: 16561.878343999997,
#  92275: 225977.95290300003,
#  92272: 107577.273014,
#  92267: 392178.10155900003,
#  92258: 185743.477304,
#  ...}

# %%
def printPtcl(ptcl, indent = ">"):
    print("\n", indent , "Particle : " , ptcl["allEvents"][0][2] , " Energy : " , (ptcl["allEvents"][0][3] + ptcl["allEvents"][0][5]) / 1e3 , " keV ")
    for child in ptcl["children"].values():
        printPtcl(child, "---" + indent)

# %%
used = []

# %%
used

# %%
ID = 0
while True:
    for k in OneSIDtoEdep:
        if np.abs(IDtoEdep[k] / 1000.0 - 63) < 1 and k not in used:
            ID = k
            used.append(k)
            break

print(ID)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-260f17d005f2> in <module>
#       1 ID = 0
#       2 while True:
# ----> 3     for k in OneSIDtoEdep:
#       4         if np.abs(IDtoEdep[k] / 1000.0 - 63) < 1 and k not in used:
#       5             ID = k
#
# NameError: name 'OneSIDtoEdep' is not defined

# %%
printPtcl(ptclTree[ID])
# Out:
#  > Particle :  neutron  Energy :  100.0  keV
#
#  ---> Particle :  proton  Energy :  63.86887145  keV

# %%
def allEnergy(ptcl):
    row = min(ptcl["allEvents"], key = lambda x : x[5])
    energy = row[5]
    for child in ptcl["children"].values():
        energy += allEnergy(child)
    return energy

# %%
allEnergy(ptclTree[1])
# Out:
# 517.380147

# %%
for ID in ptclTree:
    print(allEnergy(ptclTree[ID]), "\t" , IDtoEdep[ID])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-90448d9a338a> in <module>
#       1 for ID in ptclTree:
# ----> 2     print(allEnergy(ptclTree[ID]), "\t" , IDtoEdep[ID])
#
# KeyError: 1000000
